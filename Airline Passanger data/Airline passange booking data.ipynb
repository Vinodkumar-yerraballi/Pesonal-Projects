# %%
# Import the Standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px
import plotly.io as pio
import matplotlib.image as mpimg
import plotly.graph_objects as go
warnings.filterwarnings('ignore')

# %%
# Load the data
data=pd.read_csv('C://Users//Admin//Downloads//archive//Passanger_booking_data.csv')
data.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            6        Tue  AKLHGH      Australia                    0
# 1            7        Sat  AKLDEL    New Zealand                    1
# 2            3        Sat  AKLDEL    New Zealand                    0
# 3           17        Wed  AKLDEL          India                    1
# 4            4        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             7.21
# 1                     0                      0             5.52
# 2                     0                      0             5.52
# 3                     1                      0             5.52
# 4                     0                      1             5.52
#
#    booking_complete
# 0                 1
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# # Data Preprocessing
# - In the data preprocessing phase, we first examined the shape of the data to understand its dimensions.
# - Next, we checked for null values in the dataset and removed them if any were found.
# - Additionally, we performed a check for duplicate values and replaced them to ensure data integrity.
# - To gain insights into the relationships between different variables, we visualized the correlation map using a heatmap. This visualization allowed us to identify patterns and dependencies among the features in the dataset, helping us understand the interplay between various attribute

# %%
data.columns
# Out:
# Index(['num_passengers', 'sales_channel', 'trip_type', 'purchase_lead',
#        'length_of_stay', 'flight_hour', 'flight_day', 'route',
#        'booking_origin', 'wants_extra_baggage', 'wants_preferred_seat',
#        'wants_in_flight_meals', 'flight_duration', 'booking_complete'],
#       dtype='object')

# %%
#Checking the data shape
print(f'The dataset contains {data.shape[0]} rows and {data.shape[1]} columns')
# Out:
# The dataset contains 50002 rows and 14 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50002 entries, 0 to 50001
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50002 non-null  int64
#  1   sales_channel          50002 non-null  object
#  2   trip_type              50002 non-null  object
#  3   purchase_lead          50002 non-null  int64
#  4   length_of_stay         50002 non-null  int64
#  5   flight_hour            50002 non-null  int64
#  6   flight_day             50002 non-null  object
#  7   route                  50002 non-null  object
#  8   booking_origin         50002 non-null  object
#  9   wants_extra_baggage    50002 non-null  int64
#  10  wants_preferred_seat   50002 non-null  int64
#  11  wants_in_flight_meals  50002 non-null  int64
#  12  flight_duration        50002 non-null  float64
#  13  booking_complete       50002 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.3+ MB

# %%
# Stastic about the data set
data.describe().style.background_gradient(cmap='bone_r')
# Out:
# <style type="text/css">
# #T_e7ef4_row0_col0, #T_e7ef4_row0_col1, #T_e7ef4_row0_col2, #T_e7ef4_row0_col3, #T_e7ef4_row0_col4, #T_e7ef4_row0_col5, #T_e7ef4_row0_col6, #T_e7ef4_row0_col7, #T_e7ef4_row0_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e7ef4_row1_col0, #T_e7ef4_row1_col1, #T_e7ef4_row1_col2, #T_e7ef4_row1_col3, #T_e7ef4_row1_col4, #T_e7ef4_row1_col5, #T_e7ef4_row1_col6, #T_e7ef4_row1_col7, #T_e7ef4_row1_col8, #T_e7ef4_row2_col0, #T_e7ef4_row2_col1, #T_e7ef4_row2_col2, #T_e7ef4_row2_col3, #T_e7ef4_row2_col4, #T_e7ef4_row2_col5, #T_e7ef4_row2_col6, #T_e7ef4_row2_col7, #T_e7ef4_row2_col8, #T_e7ef4_row3_col0, #T_e7ef4_row3_col1, #T_e7ef4_row3_col2, #T_e7ef4_row3_col3, #T_e7ef4_row3_col4, #T_e7ef4_row3_col5, #T_e7ef4_row3_col6, #T_e7ef4_row3_col7, #T_e7ef4_row3_col8, #T_e7ef4_row4_col0, #T_e7ef4_row4_col1, #T_e7ef4_row4_col2, #T_e7ef4_row4_col3, #T_e7ef4_row4_col4, #T_e7ef4_row4_col5, #T_e7ef4_row4_col6, #T_e7ef4_row4_col7, #T_e7ef4_row4_col8, #T_e7ef4_row5_col0, #T_e7ef4_row5_col1, #T_e7ef4_row5_col2, #T_e7ef4_row5_col3, #T_e7ef4_row5_col4, #T_e7ef4_row5_col5, #T_e7ef4_row5_col6, #T_e7ef4_row5_col7, #T_e7ef4_row5_col8, #T_e7ef4_row6_col0, #T_e7ef4_row6_col1, #T_e7ef4_row6_col2, #T_e7ef4_row6_col3, #T_e7ef4_row6_col4, #T_e7ef4_row6_col5, #T_e7ef4_row6_col6, #T_e7ef4_row6_col7, #T_e7ef4_row6_col8, #T_e7ef4_row7_col0, #T_e7ef4_row7_col3, #T_e7ef4_row7_col4, #T_e7ef4_row7_col5, #T_e7ef4_row7_col6, #T_e7ef4_row7_col7, #T_e7ef4_row7_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_e7ef4_row7_col1 {
#   background-color: #fafcfb;
#   color: #000000;
# }
# #T_e7ef4_row7_col2 {
#   background-color: #fbfcfc;
#   color: #000000;
# }
# </style>
# <table id="T_e7ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7ef4_level0_col0" class="col_heading level0 col0" >num_passengers</th>
#       <th id="T_e7ef4_level0_col1" class="col_heading level0 col1" >purchase_lead</th>
#       <th id="T_e7ef4_level0_col2" class="col_heading level0 col2" >length_of_stay</th>
#       <th id="T_e7ef4_level0_col3" class="col_heading level0 col3" >flight_hour</th>
#       <th id="T_e7ef4_level0_col4" class="col_heading level0 col4" >wants_extra_baggage</th>
#       <th id="T_e7ef4_level0_col5" class="col_heading level0 col5" >wants_preferred_seat</th>
#       <th id="T_e7ef4_level0_col6" class="col_heading level0 col6" >wants_in_flight_meals</th>
#       <th id="T_e7ef4_level0_col7" class="col_heading level0 col7" >flight_duration</th>
#       <th id="T_e7ef4_level0_col8" class="col_heading level0 col8" >booking_complete</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7ef4_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e7ef4_row0_col0" class="data row0 col0" >50002.000000</td>
#       <td id="T_e7ef4_row0_col1" class="data row0 col1" >50002.000000</td>
#       <td id="T_e7ef4_row0_col2" class="data row0 col2" >50002.000000</td>
#       <td id="T_e7ef4_row0_col3" class="data row0 col3" >50002.000000</td>
#       <td id="T_e7ef4_row0_col4" class="data row0 col4" >50002.000000</td>
#       <td id="T_e7ef4_row0_col5" class="data row0 col5" >50002.000000</td>
#       <td id="T_e7ef4_row0_col6" class="data row0 col6" >50002.000000</td>
#       <td id="T_e7ef4_row0_col7" class="data row0 col7" >50002.000000</td>
#       <td id="T_e7ef4_row0_col8" class="data row0 col8" >50002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_e7ef4_row1_col0" class="data row1 col0" >1.591256</td>
#       <td id="T_e7ef4_row1_col1" class="data row1 col1" >84.940582</td>
#       <td id="T_e7ef4_row1_col2" class="data row1 col2" >23.044778</td>
#       <td id="T_e7ef4_row1_col3" class="data row1 col3" >9.066277</td>
#       <td id="T_e7ef4_row1_col4" class="data row1 col4" >0.668773</td>
#       <td id="T_e7ef4_row1_col5" class="data row1 col5" >0.296968</td>
#       <td id="T_e7ef4_row1_col6" class="data row1 col6" >0.427143</td>
#       <td id="T_e7ef4_row1_col7" class="data row1 col7" >7.277524</td>
#       <td id="T_e7ef4_row1_col8" class="data row1 col8" >0.149574</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_e7ef4_row2_col0" class="data row2 col0" >1.020167</td>
#       <td id="T_e7ef4_row2_col1" class="data row2 col1" >90.450548</td>
#       <td id="T_e7ef4_row2_col2" class="data row2 col2" >33.887171</td>
#       <td id="T_e7ef4_row2_col3" class="data row2 col3" >5.412569</td>
#       <td id="T_e7ef4_row2_col4" class="data row2 col4" >0.470659</td>
#       <td id="T_e7ef4_row2_col5" class="data row2 col5" >0.456927</td>
#       <td id="T_e7ef4_row2_col6" class="data row2 col6" >0.494668</td>
#       <td id="T_e7ef4_row2_col7" class="data row2 col7" >1.496854</td>
#       <td id="T_e7ef4_row2_col8" class="data row2 col8" >0.356657</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_e7ef4_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_e7ef4_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_e7ef4_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_e7ef4_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_e7ef4_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_e7ef4_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_e7ef4_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_e7ef4_row3_col7" class="data row3 col7" >4.670000</td>
#       <td id="T_e7ef4_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_e7ef4_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_e7ef4_row4_col1" class="data row4 col1" >21.000000</td>
#       <td id="T_e7ef4_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_e7ef4_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_e7ef4_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_e7ef4_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_e7ef4_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_e7ef4_row4_col7" class="data row4 col7" >5.620000</td>
#       <td id="T_e7ef4_row4_col8" class="data row4 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_e7ef4_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_e7ef4_row5_col1" class="data row5 col1" >51.000000</td>
#       <td id="T_e7ef4_row5_col2" class="data row5 col2" >17.000000</td>
#       <td id="T_e7ef4_row5_col3" class="data row5 col3" >9.000000</td>
#       <td id="T_e7ef4_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_e7ef4_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_e7ef4_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_e7ef4_row5_col7" class="data row5 col7" >7.570000</td>
#       <td id="T_e7ef4_row5_col8" class="data row5 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_e7ef4_row6_col0" class="data row6 col0" >2.000000</td>
#       <td id="T_e7ef4_row6_col1" class="data row6 col1" >115.000000</td>
#       <td id="T_e7ef4_row6_col2" class="data row6 col2" >28.000000</td>
#       <td id="T_e7ef4_row6_col3" class="data row6 col3" >13.000000</td>
#       <td id="T_e7ef4_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_e7ef4_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_e7ef4_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_e7ef4_row6_col7" class="data row6 col7" >8.830000</td>
#       <td id="T_e7ef4_row6_col8" class="data row6 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7ef4_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_e7ef4_row7_col0" class="data row7 col0" >9.000000</td>
#       <td id="T_e7ef4_row7_col1" class="data row7 c

# %%
# Checking the null values in the dataset
data.isna().sum()/len(data)*100
# Out:
# num_passengers           0.0
# sales_channel            0.0
# trip_type                0.0
# purchase_lead            0.0
# length_of_stay           0.0
# flight_hour              0.0
# flight_day               0.0
# route                    0.0
# booking_origin           0.0
# wants_extra_baggage      0.0
# wants_preferred_seat     0.0
# wants_in_flight_meals    0.0
# flight_duration          0.0
# booking_complete         0.0
# dtype: float64

# %%
# Checking the duplicate values in the data
duplicate_values=data.duplicated().sum()
print(f'The data contains {duplicate_values} duplicate values')
# Out:
# The data contains 719 duplicate values

# %%
# drop the duplicate values in the dataset we using the pandas function
data=data.drop_duplicates()
data.shape
# Out:
# (49283, 14)

# %% [markdown]
# # 💡About the DataSet
# - #### Data Size: The dataset contains 49283 rows and 14 columns.
# - #### Data Types: The data contains features with data types int64, Object, Binary and float64.
# - #### Missing Values: No column has missing values in the dataset, which is a great sign and simplifies the data cleaning process.
# - #### Unique Values: The number of unique values varies among features.
# - #### Statistical Details: The 'min', 'max', 'average', and 'standard deviation' values indicate the range and dispersion of data for each column, highlighting potential outliers or anomalies.
# - #### Irrelevant Features: All the Features seems important and useful for final evaluation.

# %%
# Visualize the correlation map
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=True,cmap='RdYlBu',fmt='.2f',
    annot_kws=None,
    linewidths=1,)
plt.title("Under stand the correlation with each columns")
plt.show()

# %% [markdown]
# # Explore Data Analysis

# %%
# Distribution of the num of passengers in the data
plt.figure(figsize=(10,8))
sns.distplot(data['purchase_lead'],hist=True,bins=50)
plt.title("The Distribution of the purchase_lead")
plt.show()

# %%
total_sales_channel=data['trip_type'].value_counts()/data['trip_type'].value_counts().sum()*100
internet=data[data['sales_channel']=='Internet'].trip_type.value_counts()
Mobile=data[data['sales_channel']=='Mobile'].trip_type.value_counts()
total_sales=data['trip_type'].value_counts()
sales_done_by_mobile=(total_sales/internet)-.108
total_sales['Color']=np.where(sales_done_by_mobile < 0, 'blue','red')
fig=go.Figure(go.Bar(x=(Mobile/total_sales).index, y= (Mobile/total_sales).values-.108, marker_color=total_sales.Color))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="347f1617-8f61-4277-b5fd-65e80589e4d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("347f1617-8f61-4277-b5fd-65e80589e4d0")) {                    Plotly.newPlot(                        "347f1617-8f61-4277-b5fd-65e80589e4d0",                        [{"marker":{"color":["red","red","red"]},"x":["CircleTrip","Color","OneWay","RoundTrip"],"y":[-0.06526495726495726,null,-0.06395854922279792,0.001532595325953262],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scatt ...
#
# var gd = document.getElementById('347f1617-8f61-4277-b5fd-65e80589e4d0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none')

# %%
# Create a bar plot visualize the top 10 most demanding origin 
data['booking_origin'].value_counts().sort_values(ascending=False).nlargest(10).plot(kind='bar',figsize=(12,6),color=['#F6CEF5','#FE2E9A','#B4045F','#F79F81','#BEF781'])
plt.title("Visualize the each country")
plt.xlabel("Countrys")
plt.xticks(rotation=90)
plt.ylabel("Count of values")
# Out:
# Text(0, 0.5, 'Count of values')

# %%
# Using the pie chart understand the how much precentage is complete there bookings
data['booking_complete'].value_counts().plot(kind='pie',
    explode=[0,0.2],
    labels=['Booking Pending',"Booking Compelted"],
    colors=['#01DFD7','#81F7BE'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("What is the booking ratio in the data")
plt.show()

# %%
# How much percentage people intrested in the trip types
trip_type=['trip_type']
for i,col in enumerate(trip_type):
    plt.figure(figsize=(10,6))
    data[col].value_counts().plot(kind='pie',explode=[0,0.5,0.3],
    labels=['RoundTrip',"OneWay",'CircleTrip'],
    colors=['#642EFE','#0B3B39','#A9F5BC'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("Visualize the trip types")
plt.show()

# %%
# Find the average flight duration of the top 20 destination in the bar charts
data.groupby('booking_origin')['flight_duration'].mean().sort_values(ascending=False).nlargest(20)\
.plot(kind='barh',figsize=(6,6))
plt.title("Averge flight duration of the top 20 countrys")
plt.xlabel("Counntry")
plt.ylabel("Average filght duration")
plt.show()

# %%
# Create countplot understand the booking status on the flight day
plt.figure(figsize=(10,5))
sns.countplot(data=data,x='flight_day',hue='booking_complete',palette=['dimgrey','crimson'])
plt.title("How many tickets booked during the each day")
plt.show()

# %%
# Create a data frame for the extra 
df=['wants_extra_baggage', 'wants_preferred_seat',
       'wants_in_flight_meals']
plt.figure(figsize=(12,5))
for i,col in enumerate(df):
    plt.subplot(1,3,i+1)
    data[col].value_counts().plot(kind='pie',explode=[0,0.2],
    labels=['Booking Pending',"Booking Compelted"],
    colors=['#5882FA','#FFFF00'],
    autopct='%1.2f%%',
    shadow=True)

# %%
# Let's Compare How much percentage of the booking complete through mobile and internet
data.groupby('sales_channel')['booking_complete'].sum().plot(kind='pie',
    explode=[0,0.2],
    labels=['Booking completed through the internet',"Booking completed through the Mobile"],
    colors=['#8258FA','#2EFE64'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("Find the how much percentage of booking completed through the channel")
# Out:
# Text(0.5, 1.0, 'Find the how much percentage of booking completed through the channel')

# %%
# create a separate data frame for Roundtrip and find the which day most of the tickets are booked
roundtrip=data[data['trip_type']=='RoundTrip']
roundtrip.groupby(['flight_day'])[['booking_complete']].value_counts().sort_values(ascending=False)\
.unstack()\
.style.background_gradient(cmap='PuBuGn_r')
# Out:
# <style type="text/css">
# #T_3fcbc_row0_col0 {
#   background-color: #4f9dc8;
#   color: #f1f1f1;
# }
# #T_3fcbc_row0_col1 {
#   background-color: #1e89a7;
#   color: #f1f1f1;
# }
# #T_3fcbc_row1_col0, #T_3fcbc_row6_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3fcbc_row1_col1 {
#   background-color: #f2e9f4;
#   color: #000000;
# }
# #T_3fcbc_row2_col0, #T_3fcbc_row2_col1 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_3fcbc_row3_col0 {
#   background-color: #288cb1;
#   color: #f1f1f1;
# }
# #T_3fcbc_row3_col1 {
#   background-color: #017165;
#   color: #f1f1f1;
# }
# #T_3fcbc_row4_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_3fcbc_row4_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_3fcbc_row5_col0 {
#   background-color: #ddd9eb;
#   color: #000000;
# }
# #T_3fcbc_row5_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_3fcbc_row6_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# </style>
# <table id="T_3fcbc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >booking_complete</th>
#       <th id="T_3fcbc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3fcbc_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >flight_day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fcbc_level0_row0" class="row_heading level0 row0" >Fri</th>
#       <td id="T_3fcbc_row0_col0" class="data row0 col0" >5647</td>
#       <td id="T_3fcbc_row0_col1" class="data row0 col1" >971</td>
#     </tr>
#     <tr>
#       <th id="T_3fcbc_level0_row1" class="row_heading level0 row1" >Mon</th>
#       <td id="T_3fcbc_row1_col0" class="data row1 col0" >6724</td>
#       <td id="T_3fcbc_row1_col1" class="data row1 col1" >1191</td>
#     </tr>
#     <tr>
#       <th id="T_3fcbc_level0_row2" class="row_heading level0 row2" >Sat</th>
#       <td id="T_3fcbc_row2_col0" class="data row2 col0" >4809</td>
#       <td id="T_3fcbc_row2_col1" class="data row2 col1" >853</td>
#     </tr>
#     <tr>
#       <th id="T_3fcbc_level0_row3" class="row_heading level0 row3" >Sun</th>
#       <td id="T_3fcbc_row3_col0" class="data row3 col0" >5465</td>
#       <td id="T_3fcbc_row3_col1" class="data row3 col1" >911</td>
#     </tr>
#     <tr>
#       <th id="T_3fcbc_level0_row4" class="row_heading level0 row4" >Thu</th>
#       <td id="T_3fcbc_row4_col0" class="data row4 col0" >6151</td>
#       <td id="T_3fcbc_row4_col1" class="data row4 col1" >1104</td>
#     </tr>
#     <tr>
#       <th id="T_3fcbc_level0_row5" class="row_heading level0 row5" >Tue</th>
#       <td id="T_3fcbc_row5_col0" class="data row5 col0" >6350</td>
#       <td id="T_3fcbc_row5_col1" class="data row5 col1" >1115</td>
#     </tr>
#     <tr>
#       <th id="T_3fcbc_level0_row6" class="row_heading level0 row6" >Wed</th>
#       <td id="T_3fcbc_row6_col0" class="data row6 col0" >6267</td>
#       <td id="T_3fcbc_row6_col1" class="data row6 col1" >1222</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a countplot to understand the each columns values in the data 
for i in data.select_dtypes(include='int'):
    plt.figure(figsize=(10,8))
    sns.countplot(data=data,x=data[i])
    plt.xlabel(f'{i}')
    plt.ylabel('Count of values')
    plt.xticks(rotation=90)
    plt.show()

# %%
# Using the groupby function we find the how many bookings are done in each day trough internet and mobile
data.groupby(['sales_channel'])[['flight_day']].value_counts().sort_values(ascending=False)\
.unstack()\
.style.background_gradient(cmap='gist_heat_r')
# Out:
# <style type="text/css">
# #T_2e565_row0_col0, #T_2e565_row0_col1, #T_2e565_row0_col2, #T_2e565_row0_col3, #T_2e565_row0_col4, #T_2e565_row0_col5, #T_2e565_row0_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2e565_row1_col0, #T_2e565_row1_col1, #T_2e565_row1_col2, #T_2e565_row1_col3, #T_2e565_row1_col4, #T_2e565_row1_col5, #T_2e565_row1_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_2e565">
#   <thead>
#     <tr>
#       <th class="index_name level0" >flight_day</th>
#       <th id="T_2e565_level0_col0" class="col_heading level0 col0" >Fri</th>
#       <th id="T_2e565_level0_col1" class="col_heading level0 col1" >Mon</th>
#       <th id="T_2e565_level0_col2" class="col_heading level0 col2" >Sat</th>
#       <th id="T_2e565_level0_col3" class="col_heading level0 col3" >Sun</th>
#       <th id="T_2e565_level0_col4" class="col_heading level0 col4" >Thu</th>
#       <th id="T_2e565_level0_col5" class="col_heading level0 col5" >Tue</th>
#       <th id="T_2e565_level0_col6" class="col_heading level0 col6" >Wed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sales_channel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e565_level0_row0" class="row_heading level0 row0" >Internet</th>
#       <td id="T_2e565_row0_col0" class="data row0 col0" >5897</td>
#       <td id="T_2e565_row0_col1" class="data row0 col1" >7197</td>
#       <td id="T_2e565_row0_col2" class="data row0 col2" >4965</td>
#       <td id="T_2e565_row0_col3" class="data row0 col3" >5591</td>
#       <td id="T_2e565_row0_col4" class="data row0 col4" >6606</td>
#       <td id="T_2e565_row0_col5" class="data row0 col5" >6827</td>
#       <td id="T_2e565_row0_col6" class="data row0 col6" >6835</td>
#     </tr>
#     <tr>
#       <th id="T_2e565_level0_row1" class="row_heading level0 row1" >Mobile</th>
#       <td id="T_2e565_row1_col0" class="data row1 col0" >788</td>
#       <td id="T_2e565_row1_col1" class="data row1 col1" >791</td>
#       <td id="T_2e565_row1_col2" class="data row1 col2" >758</td>
#       <td id="T_2e565_row1_col3" class="data row1 col3" >851</td>
#       <td id="T_2e565_row1_col4" class="data row1 col4" >717</td>
#       <td id="T_2e565_row1_col5" class="data row1 col5" >732</td>
#       <td id="T_2e565_row1_col6" class="data row1 col6" >728</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Some intresting question asked from the data
# Find the day which is more bussy and less busy days in the data
print('Which is the busy day in the flight booking counter',data['flight_day'].value_counts().idxmax())
print('\nWhich is the less busy day in the flight booking counter',data['flight_day'].value_counts().idxmin())
# And the we also do same thing about the booking origin 
print('\nWhich day booking origin is bussy',data['booking_origin'].value_counts().idxmax())
print('\nWhich day booking origin is less busy',data['booking_origin'].value_counts().idxmin())
# Out:
# Which is the busy day in the flight booking counter Mon
#
# Which is the less busy day in the flight booking counter Sat
#
# Which day booking origin is bussy Australia
#
# Which day booking origin is less busy Vanuatu

# %%
# Using the pivot table find the each origin and day which day most ticket are booked.
pd.pivot_table(data,index='booking_origin',columns='flight_day',values='booking_complete',aggfunc='mean')\
.style.background_gradient(cmap='icefire')
# Out:
# <style type="text/css">
# #T_0ec09_row0_col0 {
#   background-color: #22222b;
#   color: #f1f1f1;
# }
# #T_0ec09_row0_col1, #T_0ec09_row1_col4, #T_0ec09_row2_col4, #T_0ec09_row3_col1, #T_0ec09_row3_col4, #T_0ec09_row3_col5, #T_0ec09_row3_col6, #T_0ec09_row5_col0, #T_0ec09_row5_col1, #T_0ec09_row5_col3, #T_0ec09_row5_col4, #T_0ec09_row5_col6, #T_0ec09_row7_col0, #T_0ec09_row7_col1, #T_0ec09_row7_col3, #T_0ec09_row7_col4, #T_0ec09_row7_col5, #T_0ec09_row8_col0, #T_0ec09_row9_col0, #T_0ec09_row9_col2, #T_0ec09_row9_col3, #T_0ec09_row9_col5, #T_0ec09_row10_col4, #T_0ec09_row11_col0, #T_0ec09_row11_col1, #T_0ec09_row11_col3, #T_0ec09_row11_col4, #T_0ec09_row11_col5, #T_0ec09_row13_col5, #T_0ec09_row15_col0, #T_0ec09_row15_col1, #T_0ec09_row15_col2, #T_0ec09_row15_col4, #T_0ec09_row15_col6, #T_0ec09_row16_col0, #T_0ec09_row16_col1, #T_0ec09_row16_col3, #T_0ec09_row16_col4, #T_0ec09_row16_col6, #T_0ec09_row18_col4, #T_0ec09_row18_col5, #T_0ec09_row18_col6, #T_0ec09_row19_col1, #T_0ec09_row19_col6, #T_0ec09_row20_col5, #T_0ec09_row20_col6, #T_0ec09_row21_col0, #T_0ec09_row21_col1, #T_0ec09_row21_col2, #T_0ec09_row21_col4, #T_0ec09_row22_col3, #T_0ec09_row23_col0, #T_0ec09_row23_col3, #T_0ec09_row23_col4, #T_0ec09_row24_col2, #T_0ec09_row25_col6, #T_0ec09_row26_col0, #T_0ec09_row26_col1, #T_0ec09_row26_col2, #T_0ec09_row26_col3, #T_0ec09_row26_col5, #T_0ec09_row26_col6, #T_0ec09_row27_col2, #T_0ec09_row29_col5, #T_0ec09_row30_col4, #T_0ec09_row31_col0, #T_0ec09_row31_col2, #T_0ec09_row31_col3, #T_0ec09_row31_col5, #T_0ec09_row31_col6, #T_0ec09_row32_col3, #T_0ec09_row33_col2, #T_0ec09_row35_col0, #T_0ec09_row35_col1, #T_0ec09_row35_col2, #T_0ec09_row38_col0, #T_0ec09_row38_col1, #T_0ec09_row38_col3, #T_0ec09_row38_col4, #T_0ec09_row38_col5, #T_0ec09_row38_col6, #T_0ec09_row40_col0, #T_0ec09_row40_col1, #T_0ec09_row40_col2, #T_0ec09_row40_col5, #T_0ec09_row40_col6, #T_0ec09_row41_col1, #T_0ec09_row41_col6, #T_0ec09_row42_col5, #T_0ec09_row44_col6, #T_0ec09_row45_col3, #T_0ec09_row46_col0, #T_0ec09_row46_col2, #T_0ec09_row47_col0, #T_0ec09_row47_col2, #T_0ec09_row47_col5, #T_0ec09_row48_col0, #T_0ec09_row48_col1, #T_0ec09_row48_col3, #T_0ec09_row49_col1, #T_0ec09_row52_col0, #T_0ec09_row52_col3, #T_0ec09_row52_col4, #T_0ec09_row52_col5, #T_0ec09_row52_col6, #T_0ec09_row53_col4, #T_0ec09_row54_col0, #T_0ec09_row54_col1, #T_0ec09_row54_col2, #T_0ec09_row54_col3, #T_0ec09_row54_col5, #T_0ec09_row55_col0, #T_0ec09_row55_col1, #T_0ec09_row55_col3, #T_0ec09_row55_col4, #T_0ec09_row55_col6, #T_0ec09_row56_col0, #T_0ec09_row56_col1, #T_0ec09_row56_col2, #T_0ec09_row56_col3, #T_0ec09_row56_col4, #T_0ec09_row56_col5, #T_0ec09_row56_col6, #T_0ec09_row57_col5, #T_0ec09_row58_col1, #T_0ec09_row58_col2, #T_0ec09_row58_col3, #T_0ec09_row58_col4, #T_0ec09_row59_col2, #T_0ec09_row59_col3, #T_0ec09_row59_col4, #T_0ec09_row59_col5, #T_0ec09_row59_col6, #T_0ec09_row60_col1, #T_0ec09_row60_col3, #T_0ec09_row60_col4, #T_0ec09_row60_col5, #T_0ec09_row62_col2, #T_0ec09_row63_col1, #T_0ec09_row64_col1, #T_0ec09_row64_col3, #T_0ec09_row65_col1, #T_0ec09_row65_col2, #T_0ec09_row65_col3, #T_0ec09_row67_col6, #T_0ec09_row68_col0, #T_0ec09_row69_col0, #T_0ec09_row70_col1, #T_0ec09_row70_col5, #T_0ec09_row72_col0, #T_0ec09_row72_col1, #T_0ec09_row72_col2, #T_0ec09_row72_col3, #T_0ec09_row72_col4, #T_0ec09_row73_col0, #T_0ec09_row73_col4, #T_0ec09_row73_col6, #T_0ec09_row74_col1, #T_0ec09_row74_col4, #T_0ec09_row74_col5, #T_0ec09_row75_col3, #T_0ec09_row76_col0, #T_0ec09_row76_col1, #T_0ec09_row76_col3, #T_0ec09_row76_col5, #T_0ec09_row77_col1, #T_0ec09_row77_col2, #T_0ec09_row77_col3, #T_0ec09_row77_col6, #T_0ec09_row78_col5, #T_0ec09_row81_col1, #T_0ec09_row82_col0, #T_0ec09_row82_col4, #T_0ec09_row83_col0, #T_0ec09_row83_col5, #T_0ec09_row84_col1, #T_0ec09_row84_col4, #T_0ec09_row86_col0, #T_0ec09_row86_col1, #T_0ec09_row86_col2, #T_0ec09_row86_col3, #T_0ec09_row86_col4, #T_0ec09_row86_col6, #T_0ec09_row87_col0, #T_0ec09_row87_col2, #T_0ec09_row87_col3, #T_0ec09_row87_col4, #T_0ec09_row87_col5, #T_0ec09_row87_col6, #T_0ec09_row88_col2, #T_0ec09_row89_col0, #T_0ec09_ro ...
#   background-color: #bde7db;
#   color: #000000;
# }
# #T_0ec09_row0_col2, #T_0ec09_row9_col6, #T_0ec09_row23_col1, #T_0ec09_row23_col2, #T_0ec09_row23_col5, #T_0ec09_row31_col1, #T_0ec09_row39_col5, #T_0ec09_row45_col2, #T_0ec09_row45_col4, #T_0ec09_row46_col6, #T_0ec09_row47_col1, #T_0ec09_row55_col5, #T_0ec09_row65_col4, #T_0ec09_row65_col5, #T_0ec09_row66_col1, #T_0ec09_row74_col0, #T_0ec09_row75_col5, #T_0ec09_row77_col4, #T_0ec09_row78_col3, #T_0ec09_row79_col6, #T_0ec09_row102_col1 {
#   background-color: #ffd4ac;
#   color: #000000;
# }
# #T_0ec09_row0_col3, #T_0ec09_row12_col6, #T_0ec09_row48_col4, #T_0ec09_row57_col2, #T_0ec09_row76_col4, #T_0ec09_row80_col4, #T_0ec09_row90_col5, #T_0ec09_row90_col6 {
#   background-color: #4167c7;
#   color: #f1f1f1;
# }
# #T_0ec09_row0_col4, #T_0ec09_row0_col5 {
#   background-color: #87c2cf;
#   color: #000000;
# }
# #T_0ec09_row0_col6, #T_0ec09_row28_col5, #T_0ec09_row57_col6 {
#   background-color: #282739;
#   color: #f1f1f1;
# }
# #T_0ec09_row1_col0, #T_0ec09_row1_col1, #T_0ec09_row1_col2, #T_0ec09_row1_col3, #T_0ec09_row1_col5, #T_0ec09_row1_col6, #T_0ec09_row2_col0, #T_0ec09_row2_col1, #T_0ec09_row2_col2, #T_0ec09_row2_col3, #T_0ec09_row2_col5, #T_0ec09_row2_col6, #T_0ec09_row3_col0, #T_0ec09_row3_col2, #T_0ec09_row3_col3, #T_0ec09_row5_col2, #T_0ec09_row5_col5, #T_0ec09_row6_col0, #T_0ec09_row6_col1, #T_0ec09_row6_col3, #T_0ec09_row6_col5, #T_0ec09_row6_col6, #T_0ec09_row8_col1, #T_0ec09_row8_col2, #T_0ec09_row8_col3, #T_0ec09_row8_col4, #T_0ec09_row8_col5, #T_0ec09_row8_col6, #T_0ec09_row9_col1, #T_0ec09_row9_col4, #T_0ec09_row10_col0, #T_0ec09_row10_col1, #T_0ec09_row10_col2, #T_0ec09_row10_col3, #T_0ec09_row10_col5, #T_0ec09_row10_col6, #T_0ec09_row11_col2, #T_0ec09_row11_col6, #T_0ec09_row13_col0, #T_0ec09_row13_col1, #T_0ec09_row13_col2, #T_0ec09_row13_col3, #T_0ec09_row13_col4, #T_0ec09_row13_col6, #T_0ec09_row16_col2, #T_0ec09_row18_col0, #T_0ec09_row18_col1, #T_0ec09_row18_col2, #T_0ec09_row18_col3, #T_0ec09_row19_col0, #T_0ec09_row19_col2, #T_0ec09_row19_col3, #T_0ec09_row19_col4, #T_0ec09_row19_col5, #T_0ec09_row20_col0, #T_0ec09_row20_col1, #T_0ec09_row20_col2, #T_0ec09_row20_col3, #T_0ec09_row20_col4, #T_0ec09_row21_col3, #T_0ec09_row21_col5, #T_0ec09_row22_col0, #T_0ec09_row22_col1, #T_0ec09_row22_col2, #T_0ec09_row22_col4, #T_0ec09_row22_col5, #T_0ec09_row22_col6, #T_0ec09_row23_col6, #T_0ec09_row24_col0, #T_0ec09_row24_col1, #T_0ec09_row24_col3, #T_0ec09_row24_col4, #T_0ec09_row24_col5, #T_0ec09_row24_col6, #T_0ec09_row25_col0, #T_0ec09_row25_col1, #T_0ec09_row25_col2, #T_0ec09_row25_col3, #T_0ec09_row25_col4, #T_0ec09_row25_col5, #T_0ec09_row26_col4, #T_0ec09_row29_col0, #T_0ec09_row29_col1, #T_0ec09_row29_col2, #T_0ec09_row29_col3, #T_0ec09_row29_col4, #T_0ec09_row29_col6, #T_0ec09_row30_col0, #T_0ec09_row30_col1, #T_0ec09_row30_col2, #T_0ec09_row30_col3, #T_0ec09_row30_col5, #T_0ec09_row30_col6, #T_0ec09_row31_col4, #T_0ec09_row32_col0, #T_0ec09_row32_col1, #T_0ec09_row32_col2, #T_0ec09_row32_col4, #T_0ec09_row32_col5, #T_0ec09_row32_col6, #T_0ec09_row33_col0, #T_0ec09_row33_col1, #T_0ec09_row33_col3, #T_0ec09_row33_col4, #T_0ec09_row33_col5, #T_0ec09_row33_col6, #T_0ec09_row35_col3, #T_0ec09_row35_col4, #T_0ec09_row35_col5, #T_0ec09_row35_col6, #T_0ec09_row38_col2, #T_0ec09_row39_col0, #T_0ec09_row39_col1, #T_0ec09_row39_col2, #T_0ec09_row39_col3, #T_0ec09_row39_col4, #T_0ec09_row39_col6, #T_0ec09_row40_col3, #T_0ec09_row40_col4, #T_0ec

# %% [markdown]
# # Observations:
# - During the Exploratory Data Analysis (EDA) phase, we identified several interesting insights.
# - The distribution plot revealed that the majority of purchase leads fall within the range of 200 to 400.
# - Australia recorded the highest number of purchase leads, followed by Malaysia in second place.
# - Only 15% of the leads resulted in ticket bookings, indicating that 85% did not convert.
# - Countries like Jordan and New Zealand had a higher average flight duration compared to others.
# - The pie chart showed that 92% of bookings were completed through the internet, while 8% were completed via mobile devices.

# %% [markdown]
# # Machine Learning Modeling
# - Firstly, we utilized the label encoder to convert categorical columns into numerical values, enabling us to work with these features in our machine learning models.
#
# - Next, we divided the data into independent and dependent variables. To ensure uniformity in the data, we applied normalization techniques.
#
# - Subsequently, we split the data into training and testing sets, reserving 25% of the data for testing purposes, thus allowing us to evaluate the model's performance on unseen data.
#
# - We then proceeded to create a function for machine learning modeling. With this function, we could apply various classification algorithms to the data and compare their performance to determine the most suitable model for our task.

# %%
# Import the all required libraries for machine learning modeling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
# Covert the categorical data into the numerical using the labelencoder
for col in data.select_dtypes(include='object').columns:
    label_encoder=LabelEncoder()
    label_encoder.fit(data[col].unique())
    data[col]=label_encoder.transform(data[col])

# %%
#Divided the data into independent and dependent variables
X=data.drop(['booking_complete','purchase_lead','route'],axis=1)
y=data['booking_complete']
# Scalling the data 
scaler=StandardScaler()
X=scaler.fit_transform(X)
#Split the data into train and test data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=120)

# %%
# Create a function for machine learning model
def model_bulding(model,X_train,X_test,y_train,y_test):
    print(f'Name of the {model}')
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    score=accuracy_score(y_test,y_pred)
    print(f'\nThe Accuracy_score is {score*100:.2f}')
    print(f'\n{classification_report(y_test,y_pred)}')
    print(f'\n{confusion_matrix(y_test,y_pred)}')
    print('__'*20)

# %%
# Create all model into the dictionary formate
models={
    'logistic':LogisticRegression(),
    'decisiontree':DecisionTreeClassifier(),
    'radnom':RandomForestClassifier(),
    'Kneighbors':KNeighborsClassifier(),
    'xGB':XGBClassifier(),
    'Cat':CatBoostClassifier(iterations=1)
    
}

# %%
# Then iterating through the each model and visualize the classification and confusion reports
for i in range(len(models)):
    model=list(models.values())[i]
    name=list(models.keys())[i]
    model_bulding(model,X_train,X_test,y_train,y_test)
# Out:
# Name of the LogisticRegression()
#
# The Accuracy_score is 84.95
#
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      8374
#            1       0.00      0.00      0.00      1483
#
#     accuracy                           0.85      9857
#    macro avg       0.42      0.50      0.46      9857
# weighted avg       0.72      0.85      0.78      9857
#
#
# [[8374    0]
#  [1483    0]]
# ________________________________________
# Name of the DecisionTreeClassifier()
#
# The Accuracy_score is 76.90
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      8374
#            1       0.26      0.30      0.28      1483
#
#     accuracy                           0.77      9857
#    macro avg       0.57      0.58      0.57      9857
# weighted avg       0.78      0.77      0.77      9857
#
#
# [[7137 1237]
#  [1040  443]]
# ________________________________________
# Name of the RandomForestClassifier()
#
# The Accuracy_score is 83.82
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      8374
#            1       0.38      0.12      0.18      1483
#
#     accuracy                           0.84      9857
#    macro avg       0.62      0.54      0.54      9857
# weighted avg       0.79      0.84      0.80      9857
#
#
# [[8088  286]
#  [1309  174]]
# ________________________________________
# Name of the KNeighborsClassifier()
#
# The Accuracy_score is 83.44
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      8374
#            1       0.35      0.12      0.18      1483
#
#     accuracy                           0.83      9857
#    macro avg       0.61      0.54      0.54      9857
# weighted avg       0.78      0.83      0.80      9857
#
#
# [[8047  327]
#  [1305  178]]
# ________________________________________
# Name of the XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)
#
# The Accuracy_score is 85.06
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      8374
#            1       0.52      0.10      0.16      1483
#
#     accuracy                           0.85      9857
#    macro avg       0.69      0.54      0.54      9857
# weighted avg       0.81      0.85      0.80      9857
#
#
# [[8239  135]
#  [1338  145]]
# ________________________________________
# Name of the <catboost.core.CatBoostClassifier object at 0x0000015DA8266580>
# Learning rate set to 0.5
# 0:	learn: 0.4976508	total: 161ms	remaining: 0us
#
# The Accuracy_score is 84.95
#
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      8374
#            1       0.00      0.00      0.00      1483
#
#     accuracy                           0.85      9857
#    macro avg       0.42      0.50      0.46      9857
# weighted avg       0.72      0.85      0.78      9857
#
#
# [[8374    0]
#  [1483    0]]
# ________________________________________

# %% [markdown]
# # About the project:
# - Some interesting insights are observed in the dataset. It appears that the majority of people, approximately 91%, did not book their tickets, while only 9% of the people showed interest in booking. This highlights the need to enhance the quality of extra services such as luggage handling, specific seat selection, and meal options, as these factors seem to have a significant impact on customers' decisions. Additionally, we could consider incorporating online advertisements to attract more bookings.
#
# - Furthermore, it is notable that most of the trips are round trips. To capitalize on this trend, we should focus on promoting and improving the experience for round trips while also considering offering advertising and incentives for one-way and circular trips. By understanding these patterns and preferences, we can tailor our marketing strategies to target specific trip types and attract more customers to book their tickets.
